# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://admin-poltrona:N2YnzBBqHSL5Pnw@poltrona-cluster.rmucu.mongodb.net/covid_data?retryWrites=true&w=majority")

# %%
db = client.covid_data

# %% [markdown]
# # Coleções disponíveis

# %%
db.list_collection_names()
# Out:
# ['covid_summary', 'countries', 'first_cases']

# %%
covid_summary = db.covid_summary
countries = db.countries
first_cases = db.first_cases

# %% [markdown]
# # Recupera todas as informações de um país

# %%
def get_country_info(country_code: str) -> dict:
    summary = covid_summary.find_one({"CountryCode": country_code})
    first = first_cases.find_one({"country_code": country_code})
    if first:
        return {**summary, **{"first_case": first["first_case"]}}
    return summary

# %% [markdown]
# # Listagem de todas as informações de todos os paises

# %%
list(map(get_country_info, map(lambda x: x["ISO2"], countries.find({}))))
# Out:
# [None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c5'),
#   'Country': 'France',
#   'CountryCode': 'FR',
#   'Slug': 'france',
#   'NewConfirmed': 248,
#   'TotalConfirmed': 2275677,
#   'NewDeaths': 1,
#   'TotalDeaths': 52822,
#   'NewRecovered': 0,
#   'TotalRecovered': 167915,
#   'first_case': '2020-01-24T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1fe'),
#   'Country': 'Morocco',
#   'CountryCode': 'MA',
#   'Slug': 'morocco',
#   'NewConfirmed': 4346,
#   'TotalConfirmed': 364190,
#   'NewDeaths': 70,
#   'TotalDeaths': 5985,
#   'NewRecovered': 4044,
#   'TotalRecovered': 314237,
#   'first_case': '2020-03-02T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f20d'),
#   'Country': 'Papua New Guinea',
#   'CountryCode': 'PG',
#   'Slug': 'papua-new-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 669,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 597,
#   'first_case': '2020-03-20T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f212'),
#   'Country': 'Portugal',
#   'CountryCode': 'PT',
#   'Slug': 'portugal',
#   'NewConfirmed': 3384,
#   'TotalConfirmed': 303846,
#   'NewDeaths': 68,
#   'TotalDeaths': 4645,
#   'NewRecovered': 2569,
#   'TotalRecovered': 223446,
#   'first_case': '2020-03-02T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f18d'),
#   'Country': 'Andorra',
#   'CountryCode': 'AD',
#   'Slug': 'andorra',
#   'NewConfirmed': 52,
#   'TotalConfirmed': 6842,
#   'NewDeaths': 0,
#   'TotalDeaths': 76,
#   'NewRecovered': 48,
#   'TotalRecovered': 5988,
#   'first_case': '2020-03-02T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ad'),
#   'Country': 'China',
#   'CountryCode': 'CN',
#   'Slug': 'china',
#   'NewConfirmed': 120,
#   'TotalConfirmed': 93113,
#   'NewDeaths': 1,
#   'TotalDeaths': 4744,
#   'NewRecovered': 50,
#   'TotalRecovered': 87101,
#   'first_case': '2020-01-22T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f243'),
#   'Country': 'Venezuela (Bolivarian Republic)',
#   'CountryCode': 'VE',
#   'Slug': 'venezuela',
#   'NewConfirmed': 446,
#   'TotalConfirmed': 103067,
#   'NewDeaths': 4,
#   'TotalDeaths': 905,
#   'NewRecovered': 468,
#   'TotalRecovered': 98030,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1fd'),
#   'Country': 'Montenegro',
#   'CountryCode': 'ME',
#   'Slug': 'montenegro',
#   'NewConfirmed': 502,
#   'TotalConfirmed': 36351,
#   'NewDeaths': 6,
#   'TotalDeaths': 510,
#   'NewRecovered': 772,
#   'TotalRecovered': 25409,
#   'first_case': '2020-03-17T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f202'),
#   'Country': 'Nepal',
#   'CountryCode': 'NP',
#   'Slug': 'nepal',
#   'NewConfirmed': 2794,
#   'TotalConfirmed': 236246,
#   'NewDeaths': 9,
#   'TotalDeaths': 1538,
#   'NewRecovered': 1567,
#   'TotalRecovered': 218161,
#   'first_case': '2020-01-25T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f192'),
#   'Country': 'Australia',
#   'CountryCode': 'AU',
#   'Slug': 'australia',
#   'NewConfirmed': 16,
#   'TotalConfirmed': 27939,
#   'NewDeaths': 0,
#   'TotalDeaths': 908,
#   'NewRecovered': 8,
#   'TotalRecovered': 25614,
#   'first_case': '2020-01-26T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b0'),
#   'Country': 'Congo (Brazzaville)',
#   'CountryCode': 'CG',
#   'Slug': 'congo-brazzaville',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5774,
#   'NewDeaths': 0,
#   'TotalDeaths': 94,
#   'NewRecovered': 0,
#   'TotalRecovered': 4988,
#   'first_case': '2020-03-15T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c2'),
#   'Country': 'Ethiopia',
#   'CountryCode': 'ET',
#   'Slug': 'ethiopia',
#   'NewConfirmed': 430,
#   'TotalConfirmed': 110984,
#   'NewDeaths': 6,
#   'TotalDeaths': 1715,
#   'NewRecovered': 1150,
#   'TotalRecovered': 76067,
#   'first_case': '2020-03-13T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ee'),
#   'Country': 'Macao, SAR China',
#   'CountryCode': 'MO',
#   'Slug': 'macao-sar-china',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 0,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0},
#  {'_id': ObjectId('5fc9391d328335e0ae73f203'),
#   'Country': 'Netherlands',
#   'CountryCode': 'NL',
#   'Slug': 'netherlands',
#   'NewConfirmed': 4921,
#   'TotalConfirmed': 532444,
#   'NewDeaths': 66,
#   'TotalDeaths': 9504,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'first_case': '2020-02-27T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f23a'),
#   'Country': 'Turkey',
#   'CountryCode': 'TR',
#   'Slug': 'turkey',
#   'NewConfirmed': 31923,
#   'TotalConfirmed': 700880,
#   'NewDeaths': 193,
#   'TotalDeaths': 14129,
#   'NewRecovered': 4821,
#   'TotalRecovered': 414141,
#   'first_case': '2020-03-11T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f206'),
#   'Country': 'Niger',
#   'CountryCode': 'NE',
#   'Slug': 'niger',
#   'NewConfirmed': 54,
#   'TotalConfirmed': 1640,
#   'NewDeaths': 1,
#   'TotalDeaths': 76,
#   'NewRecovered': 8,
#   'TotalRecovered': 1227,
#   'first_case': '2020-03-20T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f3'),
#   'Country': 'Maldives',
#   'CountryCode': 'MV',
#   'Slug': 'maldives',
#   'NewConfirmed': 21,
#   'TotalConfirmed': 13070,
#   'NewDeaths': 0,
#   'TotalDeaths': 47,
#   'NewRecovered': 33,
#   'TotalRecovered': 12001,
#   'first_case': '2020-03-08T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f227'),
#   'Country': 'Somalia',
#   'CountryCode': 'SO',
#   'Slug': 'somalia',
#   'NewConfirmed': 74,
#   'TotalConfirmed': 4525,
#   'NewDeaths': 8,
#   'TotalDeaths': 121,
#   'NewRecovered': 63,
#   'TotalRecovered': 3480,
#   'first_case': '2020-03-16T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f22e'),
#   'Country': 'Swaziland',
#   'CountryCode': 'SZ',
#   'Slug': 'swaziland',
#   'NewConfirmed': 13,
#   'TotalConfirmed': 6455,
#   'NewDeaths': 0,
#   'TotalDeaths': 122,
#   'NewRecovered': 15,
#   'TotalRecovered': 6032,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f198'),
#   'Country': 'Barbados',
#   'CountryCode': 'BB',
#   'Slug': 'barbados',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 279,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 255,
#   'first_case': '2020-03-17T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d5'),
#   'Country': 'Iceland',
#   'CountryCode': 'IS',
#   'Slug': 'iceland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5413,
#   'NewDeaths': 0,
#   'TotalDeaths': 27,
#   'NewRecovered': 0,
#   'TotalRecovered': 5187,
#   'first_case': '2020-02-28T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d6'),
#   'Country': 'India',
#   'CountryCode': 'IN',
#   'Slug': 'india',
#   'NewConfirmed': 35551,
#   'TotalConfirmed': 9534964,
#   'NewDeaths': 526,
#   'TotalDeaths': 138648,
#   'NewRecovered': 40726,
#   'TotalRecovered': 8973373,
#   'first_case': '2020-01-30T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ea'),
#   'Country': 'Libya',
#   'CountryCode': 'LY',
#   'Slug': 'libya',
#   'NewConfirmed': 670,
#   'TotalConfirmed': 84087,
#   'NewDeaths': 4,
#   'TotalDeaths': 1200,
#   'NewRecovered': 503,
#   'TotalRecovered': 54712,
#   'first_case': '2020-03-24T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f22b'),
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Slug': 'sri-lanka',
#   'NewConfirmed': 878,
#   'TotalConfirmed': 25410,
#   'NewDeaths': 2,
#   'TotalDeaths': 124,
#   'NewRecovered': 487,
#   'TotalRecovered': 18304,
#   'first_case': '2020-01-27T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f197'),
#   'Country': 'Bangladesh',
#   'CountryCode': 'BD',
#   'Slug': 'bangladesh',
#   'NewConfirmed': 2198,
#   'TotalConfirmed': 469423,
#   'NewDeaths': 38,
#   'TotalDeaths': 6713,
#   'NewRecovered': 2562,
#   'TotalRecovered': 385786,
#   'first_case': '2020-03-08T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e0'),
#   'Country': 'Kazakhstan',
#   'CountryCode': 'KZ',
#   'Slug': 'kazakhstan',
#   'NewConfirmed': 777,
#   'TotalConfirmed': 176342,
#   'NewDeaths': 2,
#   'TotalDeaths': 2436,
#   'NewRecovered': 689,
#   'TotalRecovered': 148732,
#   'first_case': '2020-03-13T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f7'),
#   'Country': 'Mauritania',
#   'CountryCode': 'MR',
#   'Slug': 'mauritania',
#   'NewConfirmed': 153,
#   'TotalConfirmed': 8863,
#   'NewDeaths': 2,
#   'TotalDeaths': 179,
#   'NewRecovered': 16,
#   'TotalRecovered': 7780,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1fb'),
#   'Country': 'Monaco',
#   'CountryCode': 'MC',
#   'Slug': 'monaco',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 621,
#   'NewDeaths': 0,
#   'TotalDeaths': 3,
#   'NewRecovered': 4,
#   'TotalRecovered': 563,
#   'first_case': '2020-02-29T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f20a'),
#   'Country': 'Pakistan',
#   'CountryCode': 'PK',
#   'Slug': 'pakistan',
#   'NewConfirmed': 3499,
#   'TotalConfirmed': 406810,
#   'NewDeaths': 39,
#   'TotalDeaths': 8205,
#   'NewRecovered': 1586,
#   'TotalRecovered': 346951,
#   'first_case': '2020-02-25T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b7'),
#   'Country': "Côte d'Ivoire",
#   'CountryCode': 'CI',
#   'Slug': 'cote-divoire',
#   'NewConfirmed': 27,
#   'TotalConfirmed': 21361,
#   'NewDeaths': 0,
#   'TotalDeaths': 132,
#   'NewRecovered': 29,
#   'TotalRecovered': 21010,
#   'first_case': '2020-03-11T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e5'),
#   'Country': 'Lao PDR',
#   'CountryCode': 'LA',
#   'Slug': 'lao-pdr',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 39,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 26,
#   'first_case': '2020-03-24T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e6'),
#   'Country': 'Latvia',
#   'CountryCode': 'LV',
#   'Slug': 'latvia',
#   'NewConfirmed': 690,
#   'TotalConfirmed': 18377,
#   'NewDeaths': 14,
#   'TotalDeaths': 224,
#   'NewRecovered': 17,
#   'TotalRecovered': 1823,
#   'first_case': '2020-03-02T00:00:00Z'},
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f242'),
#   'Country': 'Vanuatu',
#   'CountryCode': 'VU',
#   'Slug': 'vanuatu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'first_case': '2020-11-10T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f191'),
#   'Country': 'Armenia',
#   'CountryCode': 'AM',
#   'Slug': 'armenia',
#   'NewConfirmed': 1264,
#   'TotalConfirmed': 137231,
#   'NewDeaths': 35,
#   'TotalDeaths': 2228,
#   'NewRecovered': 1430,
#   'TotalRecovered': 111795,
#   'first_case': '2020-03-01T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f19d'),
#   'Country': 'Bhutan',
#   'CountryCode': 'BT',
#   'Slug': 'bhutan',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 415,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 386,
#   'first_case': '2020-03-06T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d9'),
#   'Country': 'Iraq',
#   'CountryCode': 'IQ',
#   'Slug': 'iraq',
#   'NewConfirmed': 1961,
#   'TotalConfirmed': 556728,
#   'NewDeaths': 34,
#   'TotalDeaths': 12340,
#   'NewRecovered': 1743,
#   'TotalRecovered': 486313,
#   'first_case': '2020-02-24T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f8'),
#   'Country': 'Mauritius',
#   'CountryCode': 'MU',
#   'Slug': 'mauritius',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 508,
#   'NewDeaths': 0,
#   'TotalDeaths': 10,
#   'NewRecovered': 2,
#   'TotalRecovered': 465,
#   'first_case': '2020-03-18T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f18a'),
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 263,
#   'TotalConfirmed': 46980,
#   'NewDeaths': 25,
#   'TotalDeaths': 1822,
#   'NewRecovered': 119,
#   'TotalRecovered': 37026,
#   'first_case': '2020-02-24T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d4'),
#   'Country': 'Hungary',
#   'CountryCode': 'HU',
#   'Slug': 'hungary',
#   'NewConfirmed': 4136,
#   'TotalConfirmed': 225209,
#   'NewDeaths': 165,
#   'TotalDeaths': 5142,
#   'NewRecovered': 1086,
#   'TotalRecovered': 65888,
#   'first_case': '2020-03-04T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f22a'),
#   'Country': 'Spain',
#   'CountryCode': 'ES',
#   'Slug': 'spain',
#   'NewConfirmed': 9331,
#   'TotalConfirmed': 1665775,
#   'NewDeaths': 273,
#   'TotalDeaths': 45784,
#   'NewRecovered': 0,
#   'TotalRecovered': 150376,
#   'first_case': '2020-02-01T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f238'),
#   'Country': 'Trinidad and Tobago',
#   'CountryCode': 'TT',
#   'Slug': 'trinidad-and-tobago',
#   'NewConfirmed': 19,
#   'TotalConfirmed': 6704,
#   'NewDeaths': 1,
#   'TotalDeaths': 121,
#   'NewRecovered': 36,
#   'TotalRecovered': 5843,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d0'),
#   'Country': 'Guyana',
#   'CountryCode': 'GY',
#   'Slug': 'guyana',
#   'NewConfirmed': 26,
#   'TotalConfirmed': 5449,
#   'NewDeaths': 0,
#   'TotalDeaths': 151,
#   'NewRecovered': 94,
#   'TotalRecovered': 4530,
#   'first_case': '2020-03-12T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f6'),
#   'Country': 'Marshall Islands',
#   'CountryCode': 'MH',
#   'Slug': 'marshall-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 1,
#   'first_case': '2020-10-28T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f200'),
#   'Country': 'Myanmar',
#   'CountryCode': 'MM',
#   'Slug': 'myanmar',
#   'NewConfirmed': 1411,
#   'TotalConfirmed': 93600,
#   'NewDeaths': 26,
#   'TotalDeaths': 1998,
#   'NewRecovered': 1258,
#   'TotalRecovered': 72601,
#   'first_case': '2020-03-27T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ac'),
#   'Country': 'Chile',
#   'CountryCode': 'CL',
#   'Slug': 'chile',
#   'NewConfirmed': 1034,
#   'TotalConfirmed': 553898,
#   'NewDeaths': 8,
#   'TotalDeaths': 15438,
#   'NewRecovered': 1467,
#   'TotalRecovered': 529501,
#   'first_case': '2020-02-23T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c4'),
#   'Country': 'Finland',
#   'CountryCode': 'FI',
#   'Slug': 'finland',
#   'NewConfirmed': 420,
#   'TotalConfirmed': 25882,
#   'NewDeaths': 9,
#   'TotalDeaths': 408,
#   'NewRecovered': 1300,
#   'TotalRecovered': 18100,
#   'first_case': '2020-01-29T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e2'),
#   'Country': 'Korea (South)',
#   'CountryCode': 'KR',
#   'Slug': 'korea-south',
#   'NewConfirmed': 540,
#   'TotalConfirmed': 35703,
#   'NewDeaths': 3,
#   'TotalDeaths': 529,
#   'NewRecovered': 287,
#   'TotalRecovered': 28352,
#   'first_case': '2020-01-22T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f20b'),
#   'Country': 'Palestinian Territory',
#   'CountryCode': 'PS',
#   'Slug': 'palestine',
#   'NewConfirmed': 2188,
#   'TotalConfirmed': 90192,
#   'NewDeaths': 16,
#   'TotalDeaths': 763,
#   'NewRecovered': 1051,
#   'TotalRecovered': 66989,
#   'first_case': '2020-03-05T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ff'),
#   'Country': 'Mozambique',
#   'CountryCode': 'MZ',
#   'Slug': 'mozambique',
#   'NewConfirmed': 96,
#   'TotalConfirmed': 15866,
#   'NewDeaths': 1,
#   'TotalDeaths': 132,
#   'NewRecovered': 236,
#   'TotalRecovered': 14014,
#   'first_case': '2020-03-22T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f204'),
#   'Country': 'New Zealand',
#   'CountryCode': 'NZ',
#   'Slug': 'new-zealand',
#   'NewConfirmed': 9,
#   'TotalConfirmed': 2069,
#   'NewDeaths': 0,
#   'TotalDeaths': 25,
#   'NewRecovered': 11,
#   'TotalRecovered': 1974,
#   'first_case': '2020-02-28T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c1'),
#   'Country': 'Estonia',
#   'CountryCode': 'EE',
#   'Slug': 'estonia',
#   'NewConfirmed': 522,
#   'TotalConfirmed': 13019,
#   'NewDeaths': 1,
#   'TotalDeaths': 122,
#   'NewRecovered': 72,
#   'TotalRecovered': 7608,
#   'first_case': '2020-02-27T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f208'),
#   'Country': 'Norway',
#   'CountryCode': 'NO',
#   'Slug': 'norway',
#   'NewConfirmed': 378,
#   'TotalConfirmed': 36969,
#   'NewDeaths': 17,
#   'TotalDeaths': 351,
#   'NewRecovered': 0,
#   'TotalRecovered': 17998,
#   'first_case': '2020-02-26T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f219'),
#   'Country': 'Saint Kitts and Nevis',
#   'CountryCode': 'KN',
#   'Slug': 'saint-kitts-and-nevis',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 22,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 19,
#   'first_case': '2020-03-25T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f218'),
#   'Country': 'Réunion',
#   'CountryCode': 'RE',
#   'Slug': 'réunion',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 0,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0},
#  {'_id': ObjectId('5fc9391d328335e0ae73f220'),
#   'Country': 'Serbia',
#   'CountryCode': 'RS',
#   'Slug': 'serbia',
#   'NewConfirmed': 7919,
#   'TotalConfirmed': 191356,
#   'NewDeaths': 52,
#   'TotalDeaths': 1704,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'first_case': '2020-03-06T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ba'),
#   'Country': 'Dominica',
#   'CountryCode': 'DM',
#   'Slug': 'dominica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 85,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 63,
#   'first_case': '2020-03-22T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1cb'),
#   'Country': 'Greece',
#   'CountryCode': 'GR',
#   'Slug': 'greece',
#   'NewConfirmed': 2185,
#   'TotalConfirmed': 109655,
#   'NewDeaths': 89,
#   'TotalDeaths': 2606,
#   'NewRecovered': 0,
#   'TotalRecovered': 23074,
#   'first_case': '2020-02-26T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f205'),
#   'Country': 'Nicaragua',
#   'CountryCode': 'NI',
#   'Slug': 'nicaragua',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5838,
#   'NewDeaths': 0,
#   'TotalDeaths': 161,
#   'NewRecovered': 0,
#   'TotalRecovered': 4225,
#   'first_case': '2020-03-19T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f22c'),
#   'Country': 'Sudan',
#   'CountryCode': 'SD',
#   'Slug': 'sudan',
#   'NewConfirmed': 209,
#   'TotalConfirmed': 18254,
#   'NewDeaths': 10,
#   'TotalDeaths': 1265,
#   'NewRecovered': 124,
#   'TotalRecovered': 10493,
#   'first_case': '2020-03-13T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c9'),
#   'Country': 'Germany',
#   'CountryCode': 'DE',
#   'Slug': 'germany',
#   'NewConfirmed': 23275,
#   'TotalConfirmed': 1117953,
#   'NewDeaths': 482,
#   'TotalDeaths': 17659,
#   'NewRecovered': 20184,
#   'TotalRecovered': 789564,
#   'first_case': '2020-01-27T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f4'),
#   'Country': 'Mali',
#   'CountryCode': 'ML',
#   'Slug': 'mali',
#   'NewConfirmed': 75,
#   'TotalConfirmed': 4837,
#   'NewDeaths': 1,
#   'TotalDeaths': 161,
#   'NewRecovered': 22,
#   'TotalRecovered': 3263,
#   'first_case': '2020-03-25T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f20f'),
#   'Country': 'Peru',
#   'CountryCode': 'PE',
#   'Slug': 'peru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 963605,
#   'NewDeaths': 0,
#   'TotalDeaths': 35966,
#   'NewRecovered': 3917,
#   'TotalRecovered': 896978,
#   'first_case': '2020-03-06T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f21f'),
#   'Country': 'Senegal',
#   'CountryCode': 'SN',
#   'Slug': 'senegal',
#   'NewConfirmed': 66,
#   'TotalConfirmed': 16173,
#   'NewDeaths': 1,
#   'TotalDeaths': 334,
#   'NewRecovered': 30,
#   'TotalRecovered': 15657,
#   'first_case': '2020-03-02T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a7'),
#   'Country': 'Cameroon',
#   'CountryCode': 'CM',
#   'Slug': 'cameroon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24487,
#   'NewDeaths': 0,
#   'TotalDeaths': 441,
#   'NewRecovered': 0,
#   'TotalRecovered': 22177,
#   'first_case': '2020-03-06T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f241'),
#   'Country': 'Uzbekistan',
#   'CountryCode': 'UZ',
#   'Slug': 'uzbekistan',
#   'NewConfirmed': 59,
#   'TotalConfirmed': 73335,
#   'NewDeaths': 0,
#   'TotalDeaths': 611,
#   'NewRecovered': 0,
#   'TotalRecovered': 70534,
#   'first_case': '2020-03-15T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ab'),
#   'Country': 'Chad',
#   'CountryCode': 'TD',
#   'Slug': 'chad',
#   'NewConfirmed': 5,
#   'TotalConfirmed': 1705,
#   'NewDeaths': 0,
#   'TotalDeaths': 102,
#   'NewRecovered': 7,
#   'TotalRecovered': 1539,
#   'first_case': '2020-03-19T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a3'),
#   'Country': 'Bulgaria',
#   'CountryCode': 'BG',
#   'Slug': 'bulgaria',
#   'NewConfirmed': 3138,
#   'TotalConfirmed': 151913,
#   'NewDeaths': 159,
#   'TotalDeaths': 4347,
#   'NewRecovered': 2206,
#   'TotalRecovered': 55206,
#   'first_case': '2020-03-08T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1cc'),
#   'Country': 'Grenada',
#   'CountryCode': 'GD',
#   'Slug': 'grenada',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 41,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 30,
#   'first_case': '2020-03-22T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a4'),
#   'Country': 'Burkina Faso',
#   'CountryCode': 'BF',
#   'Slug': 'burkina-faso',
#   'NewConfirmed': 79,
#   'TotalConfirmed': 3010,
#   'NewDeaths': 0,
#   'TotalDeaths': 68,
#   'NewRecovered': 23,
#   'TotalRecovered': 2667,
#   'first_case': '2020-03-10T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b4'),
#   'Country': 'Cuba',
#   'CountryCode': 'CU',
#   'Slug': 'cuba',
#   'NewConfirmed': 75,
#   'TotalConfirmed': 8456,
#   'NewDeaths': 0,
#   'TotalDeaths': 136,
#   'NewRecovered': 56,
#   'TotalRecovered': 7714,
#   'first_case': '2020-03-12T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1bb'),
#   'Country': 'Dominican Republic',
#   'CountryCode': 'DO',
#   'Slug': 'dominican-republic',
#   'NewConfirmed': 895,
#   'TotalConfirmed': 145197,
#   'NewDeaths': 1,
#   'TotalDeaths': 2334,
#   'NewRecovered': 81,
#   'TotalRecovered': 115611,
#   'first_case': '2020-03-01T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f225'),
#   'Country': 'Slovenia',
#   'CountryCode': 'SI',
#   'Slug': 'slovenia',
#   'NewConfirmed': 2431,
#   'TotalConfirmed': 79566,
#   'NewDeaths': 57,
#   'TotalDeaths': 1547,
#   'NewRecovered': 1971,
#   'TotalRecovered': 57447,
#   'first_case': '2020-03-05T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f229'),
#   'Country': 'South Sudan',
#   'CountryCode': 'SS',
#   'Slug': 'south-sudan',
#   'NewConfirmed': 7,
#   'TotalConfirmed': 3118,
#   'NewDeaths': 0,
#   'TotalDeaths': 61,
#   'NewRecovered': 12,
#   'TotalRecovered': 2966,
#   'first_case': '2020-04-05T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c7'),
#   'Country': 'Gambia',
#   'CountryCode': 'GM',
#   'Slug': 'gambia',
#   'NewConfirmed': 22,
#   'TotalConfirmed': 3765,
#   'NewDeaths': 0,
#   'TotalDeaths': 123,
#   'NewRecovered': 2,
#   'TotalRecovered': 3609,
#   'first_case': '2020-03-17T00:00:00Z'},
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b5'),
#   'Country': 'Cyprus',
#   'CountryCode': 'CY',
#   'Slug': 'cyprus',
#   'NewConfirmed': 292,
#   'TotalConfirmed': 11175,
#   'NewDeaths': 3,
#   'TotalDeaths': 52,
#   'NewRecovered': 0,
#   'TotalRecovered': 2057,
#   'first_case': '2020-03-09T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f211'),
#   'Country': 'Poland',
#   'CountryCode': 'PL',
#   'Slug': 'poland',
#   'NewConfirmed': 13823,
#   'TotalConfirmed': 1013747,
#   'NewDeaths': 609,
#   'TotalDeaths': 18208,
#   'NewRecovered': 25391,
#   'TotalRecovered': 622980,
#   'first_case': '2020-03-04T00:00:00Z'},
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f20e'),
#   'Country': 'Paraguay',
#   'CountryCode': 'PY',
#   'Slug': 'paraguay',
#   'NewConfirmed': 1003,
#   'TotalConfirmed': 84482,
#   'NewDeaths': 12,
#   'TotalDeaths': 1783,
#   'NewRecovered': 516,
#   'TotalRecovered': 59465,
#   'first_case': '2020-03-08T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f224'),
#   'Country': 'Slovakia',
#   'CountryCode': 'SK',
#   'Slug': 'slovakia',
#   'NewConfirmed': 2043,
#   'TotalConfirmed': 109226,
#   'NewDeaths': 30,
#   'TotalDeaths': 898,
#   'NewRecovered': 2879,
#   'TotalRecovered': 71738,
#   'first_case': '2020-03-06T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f23f'),
#   'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Slug': 'united-states',
#   'NewConfirmed': 200070,
#   'TotalConfirmed': 13921374,
#   'NewDeaths': 3157,
#   'TotalDeaths': 273799,
#   'NewRecovered': 95547,
#   'TotalRecovered': 5322128},
#  {'_id': ObjectId('5fc9391d328335e0ae73f245'),
#   'Country': 'Western Sahara',
#   'CountryCode': 'EH',
#   'Slug': 'western-sahara',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 8,
#   'first_case': '2020-04-05T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ed'),
#   'Country': 'Luxembourg',
#   'CountryCode': 'LU',
#   'Slug': 'luxembourg',
#   'NewConfirmed': 673,
#   'TotalConfirmed': 35802,
#   'NewDeaths': 4,
#   'TotalDeaths': 334,
#   'NewRecovered': 341,
#   'TotalRecovered': 26497,
#   'first_case': '2020-02-29T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f5'),
#   'Country': 'Malta',
#   'CountryCode': 'MT',
#   'Slug': 'malta',
#   'NewConfirmed': 126,
#   'TotalConfirmed': 10101,
#   'NewDeaths': 5,
#   'TotalDeaths': 146,
#   'NewRecovered': 139,
#   'TotalRecovered': 7887,
#   'first_case': '2020-03-07T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d7'),
#   'Country': 'Indonesia',
#   'CountryCode': 'ID',
#   'Slug': 'indonesia',
#   'NewConfirmed': 5533,
#   'TotalConfirmed': 549508,
#   'NewDeaths': 118,
#   'TotalDeaths': 17199,
#   'NewRecovered': 4001,
#   'TotalRecovered': 458880,
#   'first_case': '2020-03-02T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f210'),
#   'Country': 'Philippines',
#   'CountryCode': 'PH',
#   'Slug': 'philippines',
#   'NewConfirmed': 1432,
#   'TotalConfirmed': 434357,
#   'NewDeaths': 18,
#   'TotalDeaths': 8436,
#   'NewRecovered': 223,
#   'TotalRecovered': 399005,
#   'first_case': '2020-01-30T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f19a'),
#   'Country': 'Belgium',
#   'CountryCode': 'BE',
#   'Slug': 'belgium',
#   'NewConfirmed': 3040,
#   'TotalConfirmed': 582252,
#   'NewDeaths': 125,
#   'TotalDeaths': 16911,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'first_case': '2020-02-04T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f230'),
#   'Country': 'Switzerland',
#   'CountryCode': 'CH',
#   'Slug': 'switzerland',
#   'NewConfirmed': 4786,
#   'TotalConfirmed': 335660,
#   'NewDeaths': 105,
#   'TotalDeaths': 5045,
#   'NewRecovered': 7400,
#   'TotalRecovered': 257600,
#   'first_case': '2020-02-25T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e8'),
#   'Country': 'Lesotho',
#   'CountryCode': 'LS',
#   'Slug': 'lesotho',
#   'NewConfirmed': 5,
#   'TotalConfirmed': 2142,
#   'NewDeaths': 0,
#   'TotalDeaths': 44,
#   'NewRecovered': 0,
#   'TotalRecovered': 1278,
#   'first_case': '2020-05-13T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f21b'),
#   'Country': 'Saint Vincent and Grenadines',
#   'CountryCode': 'VC',
#   'Slug': 'saint-vincent-and-the-grenadines',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 85,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 80,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d2'),
#   'Country': 'Holy See (Vatican City State)',
#   'CountryCode': 'VA',
#   'Slug': 'holy-see-vatican-city-state',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 15,
#   'first_case': '2020-03-06T00:00:00Z'},
#  None,
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f23e'),
#   'Country': 'United Kingdom',
#   'CountryCode': 'GB',
#   'Slug': 'united-kingdom',
#   'NewConfirmed': 16237,
#   'TotalConfirmed': 1663467,
#   'NewDeaths': 648,
#   'TotalDeaths': 59796,
#   'NewRecovered': 13,
#   'TotalRecovered': 3602,
#   'first_case': '2020-01-31T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f199'),
#   'Country': 'Belarus',
#   'CountryCode': 'BY',
#   'Slug': 'belarus',
#   'NewConfirmed': 1689,
#   'TotalConfirmed': 139908,
#   'NewDeaths': 8,
#   'TotalDeaths': 1174,
#   'NewRecovered': 1608,
#   'TotalRecovered': 117195,
#   'first_case': '2020-02-28T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c3'),
#   'Country': 'Fiji',
#   'CountryCode': 'FJ',
#   'Slug': 'fiji',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 42,
#   'NewDeaths': 0,
#   'TotalDeaths': 2,
#   'NewRecovered': 0,
#   'TotalRecovered': 33,
#   'first_case': '2020-03-19T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f240'),
#   'Country': 'Uruguay',
#   'CountryCode': 'UY',
#   'Slug': 'uruguay',
#   'NewConfirmed': 201,
#   'TotalConfirmed': 6225,
#   'NewDeaths': 2,
#   'TotalDeaths': 80,
#   'NewRecovered': 101,
#   'TotalRecovered': 4584,
#   'first_case': '2020-03-13T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d8'),
#   'Country': 'Iran, Islamic Republic of',
#   'CountryCode': 'IR',
#   'Slug': 'iran',
#   'NewConfirmed': 13621,
#   'TotalConfirmed': 989572,
#   'NewDeaths': 362,
#   'TotalDeaths': 48990,
#   'NewRecovered': 10091,
#   'TotalRecovered': 688054,
#   'first_case': '2020-02-19T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f233'),
#   'Country': 'Tajikistan',
#   'CountryCode': 'TJ',
#   'Slug': 'tajikistan',
#   'NewConfirmed': 38,
#   'TotalConfirmed': 12269,
#   'NewDeaths': 1,
#   'TotalDeaths': 87,
#   'NewRecovered': 37,
#   'TotalRecovered': 11677,
#   'first_case': '2020-04-30T00:00:00Z'},
#  None,
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f239'),
#   'Country': 'Tunisia',
#   'CountryCode': 'TN',
#   'Slug': 'tunisia',
#   'NewConfirmed': 2511,
#   'TotalConfirmed': 99280,
#   'NewDeaths': 99,
#   'TotalDeaths': 3359,
#   'NewRecovered': 2756,
#   'TotalRecovered': 73607,
#   'first_case': '2020-03-04T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1bf'),
#   'Country': 'Equatorial Guinea',
#   'CountryCode': 'GQ',
#   'Slug': 'equatorial-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5156,
#   'NewDeaths': 0,
#   'TotalDeaths': 85,
#   'NewRecovered': 0,
#   'TotalRecovered': 5009,
#   'first_case': '2020-03-15T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1bd'),
#   'Country': 'Egypt',
#   'CountryCode': 'EG',
#   'Slug': 'egypt',
#   'NewConfirmed': 421,
#   'TotalConfirmed': 116724,
#   'NewDeaths': 28,
#   'TotalDeaths': 6694,
#   'NewRecovered': 133,
#   'TotalRecovered': 102949,
#   'first_case': '2020-02-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f222'),
#   'Country': 'Sierra Leone',
#   'CountryCode': 'SL',
#   'Slug': 'sierra-leone',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 2416,
#   'NewDeaths': 0,
#   'TotalDeaths': 74,
#   'NewRecovered': 0,
#   'TotalRecovered': 1838,
#   'first_case': '2020-03-31T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f23c'),
#   'Country': 'Ukraine',
#   'CountryCode': 'UA',
#   'Slug': 'ukraine',
#   'NewConfirmed': 13443,
#   'TotalConfirmed': 778560,
#   'NewDeaths': 178,
#   'TotalDeaths': 13140,
#   'NewRecovered': 14284,
#   'TotalRecovered': 384961,
#   'first_case': '2020-03-03T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f246'),
#   'Country': 'Yemen',
#   'CountryCode': 'YE',
#   'Slug': 'yemen',
#   'NewConfirmed': 20,
#   'TotalConfirmed': 2217,
#   'NewDeaths': 2,
#   'TotalDeaths': 621,
#   'NewRecovered': 4,
#   'TotalRecovered': 1518,
#   'first_case': '2020-04-10T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a1'),
#   'Country': 'Brazil',
#   'CountryCode': 'BR',
#   'Slug': 'brazil',
#   'NewConfirmed': 49863,
#   'TotalConfirmed': 6436650,
#   'NewDeaths': 698,
#   'TotalDeaths': 174515,
#   'NewRecovered': 46989,
#   'TotalRecovered': 5759294,
#   'first_case': '2020-02-26T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f22d'),
#   'Country': 'Suriname',
#   'CountryCode': 'SR',
#   'Slug': 'suriname',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 5320,
#   'NewDeaths': 0,
#   'TotalDeaths': 117,
#   'NewRecovered': 3,
#   'TotalRecovered': 5200,
#   'first_case': '2020-03-14T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1cd'),
#   'Country': 'Guatemala',
#   'CountryCode': 'GT',
#   'Slug': 'guatemala',
#   'NewConfirmed': 686,
#   'TotalConfirmed': 123460,
#   'NewDeaths': 13,
#   'TotalDeaths': 4191,
#   'NewRecovered': 607,
#   'TotalRecovered': 112181,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f221'),
#   'Country': 'Seychelles',
#   'CountryCode': 'SC',
#   'Slug': 'seychelles',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 183,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 162,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f22f'),
#   'Country': 'Sweden',
#   'CountryCode': 'SE',
#   'Slug': 'sweden',
#   'NewConfirmed': 5400,
#   'TotalConfirmed': 266158,
#   'NewDeaths': 174,
#   'TotalDeaths': 6972,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'first_case': '2020-01-31T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f195'),
#   'Country': 'Bahamas',
#   'CountryCode': 'BS',
#   'Slug': 'bahamas',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7543,
#   'NewDeaths': 0,
#   'TotalDeaths': 163,
#   'NewRecovered': 0,
#   'TotalRecovered': 5934,
#   'first_case': '2020-03-16T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ae'),
#   'Country': 'Colombia',
#   'CountryCode': 'CO',
#   'Slug': 'colombia',
#   'NewConfirmed': 9297,
#   'TotalConfirmed': 1334089,
#   'NewDeaths': 183,
#   'TotalDeaths': 37117,
#   'NewRecovered': 7988,
#   'TotalRecovered': 1225635,
#   'first_case': '2020-03-06T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1cf'),
#   'Country': 'Guinea-Bissau',
#   'CountryCode': 'GW',
#   'Slug': 'guinea-bissau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2441,
#   'NewDeaths': 0,
#   'TotalDeaths': 44,
#   'NewRecovered': 0,
#   'TotalRecovered': 2327,
#   'first_case': '2020-03-25T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e1'),
#   'Country': 'Kenya',
#   'CountryCode': 'KE',
#   'Slug': 'kenya',
#   'NewConfirmed': 961,
#   'TotalConfirmed': 85130,
#   'NewDeaths': 10,
#   'TotalDeaths': 1484,
#   'NewRecovered': 854,
#   'TotalRecovered': 56464,
#   'first_case': '2020-03-13T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f20c'),
#   'Country': 'Panama',
#   'CountryCode': 'PA',
#   'Slug': 'panama',
#   'NewConfirmed': 2028,
#   'TotalConfirmed': 169339,
#   'NewDeaths': 16,
#   'TotalDeaths': 3114,
#   'NewRecovered': 1058,
#   'TotalRecovered': 146576,
#   'first_case': '2020-03-10T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f215'),
#   'Country': 'Romania',
#   'CountryCode': 'RO',
#   'Slug': 'romania',
#   'NewConfirmed': 4916,
#   'TotalConfirmed': 484550,
#   'NewDeaths': 135,
#   'TotalDeaths': 11665,
#   'NewRecovered': 10297,
#   'TotalRecovered': 371231,
#   'first_case': '2020-02-26T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f209'),
#   'Country': 'Oman',
#   'CountryCode': 'OM',
#   'Slug': 'oman',
#   'NewConfirmed': 237,
#   'TotalConfirmed': 124145,
#   'NewDeaths': 0,
#   'TotalDeaths': 1430,
#   'NewRecovered': 172,
#   'TotalRecovered': 115613,
#   'first_case': '2020-02-24T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f18b'),
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 705,
#   'TotalConfirmed': 39719,
#   'NewDeaths': 17,
#   'TotalDeaths': 839,
#   'NewRecovered': 528,
#   'TotalRecovered': 19912,
#   'first_case': '2020-03-09T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f232'),
#   'Country': 'Taiwan, Republic of China',
#   'CountryCode': 'TW',
#   'Slug': 'taiwan',
#   'NewConfirmed': 6,
#   'TotalConfirmed': 685,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 2,
#   'TotalRecovered': 570,
#   'first_case': '2020-01-22T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a8'),
#   'Country': 'Canada',
#   'CountryCode': 'CA',
#   'Slug': 'canada',
#   'NewConfirmed': 6454,
#   'TotalConfirmed': 393480,
#   'NewDeaths': 113,
#   'TotalDeaths': 12341,
#   'NewRecovered': 4972,
#   'TotalRecovered': 314529,
#   'first_case': '2020-01-26T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f235'),
#   'Country': 'Thailand',
#   'CountryCode': 'TH',
#   'Slug': 'thailand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4026,
#   'NewDeaths': 0,
#   'TotalDeaths': 60,
#   'NewRecovered': 0,
#   'TotalRecovered': 3822,
#   'first_case': '2020-01-22T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f193'),
#   'Country': 'Austria',
#   'CountryCode': 'AT',
#   'Slug': 'austria',
#   'NewConfirmed': 3972,
#   'TotalConfirmed': 289461,
#   'NewDeaths': 121,
#   'TotalDeaths': 3446,
#   'NewRecovered': 6160,
#   'TotalRecovered': 233657,
#   'first_case': '2020-02-25T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f234'),
#   'Country': 'Tanzania, United Republic of',
#   'CountryCode': 'TZ',
#   'Slug': 'tanzania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 509,
#   'NewDeaths': 0,
#   'TotalDeaths': 21,
#   'NewRecovered': 0,
#   'TotalRecovered': 183,
#   'first_case': '2020-03-16T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1fc'),
#   'Country': 'Mongolia',
#   'CountryCode': 'MN',
#   'Slug': 'mongolia',
#   'NewConfirmed': 7,
#   'TotalConfirmed': 819,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 7,
#   'TotalRecovered': 365,
#   'first_case': '2020-03-10T00:00:00Z'},
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f228'),
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Slug': 'south-africa',
#   'NewConfirmed': 4173,
#   'TotalConfirmed': 796472,
#   'NewDeaths': 65,
#   'TotalDeaths': 21709,
#   'NewRecovered': 1774,
#   'TotalRecovered': 734305,
#   'first_case': '2020-03-05T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f19f'),
#   'Country': 'Bosnia and Herzegovina',
#   'CountryCode': 'BA',
#   'Slug': 'bosnia-and-herzegovina',
#   'NewConfirmed': 1293,
#   'TotalConfirmed': 90378,
#   'NewDeaths': 46,
#   'TotalDeaths': 2773,
#   'NewRecovered': 1243,
#   'TotalRecovered': 54967,
#   'first_case': '2020-03-05T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1dc'),
#   'Country': 'Italy',
#   'CountryCode': 'IT',
#   'Slug': 'italy',
#   'NewConfirmed': 20709,
#   'TotalConfirmed': 1641610,
#   'NewDeaths': 684,
#   'TotalDeaths': 57045,
#   'NewRecovered': 38740,
#   'TotalRecovered': 823335,
#   'first_case': '2020-01-31T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f19c'),
#   'Country': 'Benin',
#   'CountryCode': 'BJ',
#   'Slug': 'benin',
#   'NewConfirmed': 40,
#   'TotalConfirmed': 3055,
#   'NewDeaths': 1,
#   'TotalDeaths': 44,
#   'NewRecovered': 0,
#   'TotalRecovered': 2839,
#   'first_case': '2020-03-16T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b8'),
#   'Country': 'Denmark',
#   'CountryCode': 'DK',
#   'Slug': 'denmark',
#   'NewConfirmed': 1586,
#   'TotalConfirmed': 84056,
#   'NewDeaths': 6,
#   'TotalDeaths': 852,
#   'NewRecovered': 1329,
#   'TotalRecovered': 66604,
#   'first_case': '2020-02-27T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1df'),
#   'Country': 'Jordan',
#   'CountryCode': 'JO',
#   'Slug': 'jordan',
#   'NewConfirmed': 3591,
#   'TotalConfirmed': 227208,
#   'NewDeaths': 52,
#   'TotalDeaths': 2854,
#   'NewRecovered': 5470,
#   'TotalRecovered': 168429,
#   'first_case': '2020-03-03T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f21c'),
#   'Country': 'San Marino',
#   'CountryCode': 'SM',
#   'Slug': 'san-marino',
#   'NewConfirmed': 37,
#   'TotalConfirmed': 1687,
#   'NewDeaths': 0,
#   'TotalDeaths': 46,
#   'NewRecovered': 6,
#   'TotalRecovered': 1340,
#   'first_case': '2020-02-27T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f236'),
#   'Country': 'Timor-Leste',
#   'CountryCode': 'TL',
#   'Slug': 'timor-leste',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 31,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 30,
#   'first_case': '2020-03-22T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f194'),
#   'Country': 'Azerbaijan',
#   'CountryCode': 'AZ',
#   'Slug': 'azerbaijan',
#   'NewConfirmed': 3942,
#   'TotalConfirmed': 129544,
#   'NewDeaths': 37,
#   'TotalDeaths': 1470,
#   'NewRecovered': 2265,
#   'TotalRecovered': 79162,
#   'first_case': '2020-03-01T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a2'),
#   'Country': 'Brunei Darussalam',
#   'CountryCode': 'BN',
#   'Slug': 'brunei',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 151,
#   'NewDeaths': 0,
#   'TotalDeaths': 3,
#   'NewRecovered': 0,
#   'TotalRecovered': 145,
#   'first_case': '2020-03-09T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e3'),
#   'Country': 'Kuwait',
#   'CountryCode': 'KW',
#   'Slug': 'kuwait',
#   'NewConfirmed': 268,
#   'TotalConfirmed': 143260,
#   'NewDeaths': 1,
#   'TotalDeaths': 882,
#   'NewRecovered': 509,
#   'TotalRecovered': 138134,
#   'first_case': '2020-02-24T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ef'),
#   'Country': 'Macedonia, Republic of',
#   'CountryCode': 'MK',
#   'Slug': 'macedonia',
#   'NewConfirmed': 945,
#   'TotalConfirmed': 63890,
#   'NewDeaths': 33,
#   'TotalDeaths': 1825,
#   'NewRecovered': 789,
#   'TotalRecovered': 40977,
#   'first_case': '2020-02-26T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1fa'),
#   'Country': 'Moldova',
#   'CountryCode': 'MD',
#   'Slug': 'moldova',
#   'NewConfirmed': 1717,
#   'TotalConfirmed': 110580,
#   'NewDeaths': 20,
#   'TotalDeaths': 2343,
#   'NewRecovered': 793,
#   'TotalRecovered': 96711,
#   'first_case': '2020-03-08T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f21a'),
#   'Country': 'Saint Lucia',
#   'CountryCode': 'LC',
#   'Slug': 'saint-lucia',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 261,
#   'NewDeaths': 0,
#   'TotalDeaths': 2,
#   'NewRecovered': 3,
#   'TotalRecovered': 141,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f23b'),
#   'Country': 'Uganda',
#   'CountryCode': 'UG',
#   'Slug': 'uganda',
#   'NewConfirmed': 374,
#   'TotalConfirmed': 21409,
#   'NewDeaths': 1,
#   'TotalDeaths': 206,
#   'NewRecovered': 0,
#   'TotalRecovered': 9044,
#   'first_case': '2020-03-21T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f18e'),
#   'Country': 'Angola',
#   'CountryCode': 'AO',
#   'Slug': 'angola',
#   'NewConfirmed': 68,
#   'TotalConfirmed': 15319,
#   'NewDeaths': 1,
#   'TotalDeaths': 351,
#   'NewRecovered': 207,
#   'TotalRecovered': 8139,
#   'first_case': '2020-03-20T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a0'),
#   'Country': 'Botswana',
#   'CountryCode': 'BW',
#   'Slug': 'botswana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10742,
#   'NewDeaths': 0,
#   'TotalDeaths': 34,
#   'NewRecovered': 0,
#   'TotalRecovered': 7912,
#   'first_case': '2020-03-30T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c0'),
#   'Country': 'Eritrea',
#   'CountryCode': 'ER',
#   'Slug': 'eritrea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 577,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 498,
#   'first_case': '2020-03-21T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1dd'),
#   'Country': 'Jamaica',
#   'CountryCode': 'JM',
#   'Slug': 'jamaica',
#   'NewConfirmed': 54,
#   'TotalConfirmed': 10864,
#   'NewDeaths': 0,
#   'TotalDeaths': 258,
#   'NewRecovered': 136,
#   'TotalRecovered': 6500,
#   'first_case': '2020-03-11T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f248'),
#   'Country': 'Zimbabwe',
#   'CountryCode': 'ZW',
#   'Slug': 'zimbabwe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10129,
#   'NewDeaths': 0,
#   'TotalDeaths': 277,
#   'NewRecovered': 0,
#   'TotalRecovered': 8643,
#   'first_case': '2020-03-20T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c6'),
#   'Country': 'Gabon',
#   'CountryCode': 'GA',
#   'Slug': 'gabon',
#   'NewConfirmed': 25,
#   'TotalConfirmed': 9239,
#   'NewDeaths': 0,
#   'TotalDeaths': 60,
#   'NewRecovered': 23,
#   'TotalRecovered': 9089,
#   'first_case': '2020-03-14T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a9'),
#   'Country': 'Cape Verde',
#   'CountryCode': 'CV',
#   'Slug': 'cape-verde',
#   'NewConfirmed': 51,
#   'TotalConfirmed': 10867,
#   'NewDeaths': 0,
#   'TotalDeaths': 106,
#   'NewRecovered': 56,
#   'TotalRecovered': 10422,
#   'first_case': '2020-03-20T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b1'),
#   'Country': 'Congo (Kinshasa)',
#   'CountryCode': 'CD',
#   'Slug': 'congo-kinshasa',
#   'NewConfirmed': 128,
#   'TotalConfirmed': 12987,
#   'NewDeaths': 1,
#   'TotalDeaths': 336,
#   'NewRecovered': 31,
#   'TotalRecovered': 11694,
#   'first_case': '2020-03-11T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b9'),
#   'Country': 'Djibouti',
#   'CountryCode': 'DJ',
#   'Slug': 'djibouti',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 5682,
#   'NewDeaths': 0,
#   'TotalDeaths': 61,
#   'NewRecovered': 0,
#   'TotalRecovered': 5587,
#   'first_case': '2020-03-18T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f1'),
#   'Country': 'Malawi',
#   'CountryCode': 'MW',
#   'Slug': 'malawi',
#   'NewConfirmed': 12,
#   'TotalConfirmed': 6040,
#   'NewDeaths': 0,
#   'TotalDeaths': 185,
#   'NewRecovered': 6,
#   'TotalRecovered': 5471,
#   'first_case': '2020-04-02T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f216'),
#   'Country': 'Russian Federation',
#   'CountryCode': 'RU',
#   'Slug': 'russia',
#   'NewConfirmed': 25043,
#   'TotalConfirmed': 2327105,
#   'NewDeaths': 580,
#   'TotalDeaths': 40630,
#   'NewRecovered': 26480,
#   'TotalRecovered': 1814442,
#   'first_case': '2020-01-31T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f21d'),
#   'Country': 'Sao Tome and Principe',
#   'CountryCode': 'ST',
#   'Slug': 'sao-tome-and-principe',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 997,
#   'NewDeaths': 0,
#   'TotalDeaths': 17,
#   'NewRecovered': 0,
#   'TotalRecovered': 934,
#   'first_case': '2020-04-06T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f19e'),
#   'Country': 'Bolivia',
#   'CountryCode': 'BO',
#   'Slug': 'bolivia',
#   'NewConfirmed': 184,
#   'TotalConfirmed': 144994,
#   'NewDeaths': 9,
#   'TotalDeaths': 8972,
#   'NewRecovered': 1178,
#   'TotalRecovered': 123673,
#   'first_case': '2020-03-11T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a6'),
#   'Country': 'Cambodia',
#   'CountryCode': 'KH',
#   'Slug': 'cambodia',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 331,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 304,
#   'first_case': '2020-01-27T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1af'),
#   'Country': 'Comoros',
#   'CountryCode': 'KM',
#   'Slug': 'comoros',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 613,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 586,
#   'first_case': '2020-04-30T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1c8'),
#   'Country': 'Georgia',
#   'CountryCode': 'GE',
#   'Slug': 'georgia',
#   'NewConfirmed': 4033,
#   'TotalConfirmed': 143376,
#   'NewDeaths': 39,
#   'TotalDeaths': 1342,
#   'NewRecovered': 4061,
#   'TotalRecovered': 121621,
#   'first_case': '2020-02-26T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ce'),
#   'Country': 'Guinea',
#   'CountryCode': 'GN',
#   'Slug': 'guinea',
#   'NewConfirmed': 24,
#   'TotalConfirmed': 13143,
#   'NewDeaths': 0,
#   'TotalDeaths': 76,
#   'NewRecovered': 109,
#   'TotalRecovered': 12154,
#   'first_case': '2020-03-13T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f223'),
#   'Country': 'Singapore',
#   'CountryCode': 'SG',
#   'Slug': 'singapore',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 58230,
#   'NewDeaths': 0,
#   'TotalDeaths': 29,
#   'NewRecovered': 5,
#   'TotalRecovered': 58144,
#   'first_case': '2020-01-23T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f247'),
#   'Country': 'Zambia',
#   'CountryCode': 'ZM',
#   'Slug': 'zambia',
#   'NewConfirmed': 35,
#   'TotalConfirmed': 17700,
#   'NewDeaths': 0,
#   'TotalDeaths': 357,
#   'NewRecovered': 27,
#   'TotalRecovered': 17086,
#   'first_case': '2020-03-18T00:00:00Z'},
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f237'),
#   'Country': 'Togo',
#   'CountryCode': 'TG',
#   'Slug': 'togo',
#   'NewConfirmed': 17,
#   'TotalConfirmed': 3014,
#   'NewDeaths': 1,
#   'TotalDeaths': 65,
#   'NewRecovered': 28,
#   'TotalRecovered': 2543,
#   'first_case': '2020-03-06T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f244'),
#   'Country': 'Viet Nam',
#   'CountryCode': 'VN',
#   'Slug': 'vietnam',
#   'NewConfirmed': 7,
#   'TotalConfirmed': 1358,
#   'NewDeaths': 0,
#   'TotalDeaths': 35,
#   'NewRecovered': 6,
#   'TotalRecovered': 1201,
#   'first_case': '2020-01-23T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f18f'),
#   'Country': 'Antigua and Barbuda',
#   'CountryCode': 'AG',
#   'Slug': 'antigua-and-barbuda',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 144,
#   'NewDeaths': 0,
#   'TotalDeaths': 4,
#   'NewRecovered': 3,
#   'TotalRecovered': 133,
#   'first_case': '2020-03-13T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b6'),
#   'Country': 'Czech Republic',
#   'CountryCode': 'CZ',
#   'Slug': 'czech-republic',
#   'NewConfirmed': 4568,
#   'TotalConfirmed': 533042,
#   'NewDeaths': 108,
#   'TotalDeaths': 8515,
#   'NewRecovered': 6422,
#   'TotalRecovered': 461599,
#   'first_case': '2020-03-01T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1be'),
#   'Country': 'El Salvador',
#   'CountryCode': 'SV',
#   'Slug': 'el-salvador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 39130,
#   'NewDeaths': 9,
#   'TotalDeaths': 1129,
#   'NewRecovered': 0,
#   'TotalRecovered': 35839,
#   'first_case': '2020-03-19T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f23d'),
#   'Country': 'United Arab Emirates',
#   'CountryCode': 'AE',
#   'Slug': 'united-arab-emirates',
#   'NewConfirmed': 1285,
#   'TotalConfirmed': 171434,
#   'NewDeaths': 4,
#   'TotalDeaths': 580,
#   'NewRecovered': 713,
#   'TotalRecovered': 156380,
#   'first_case': '2020-01-29T00:00:00Z'},
#  None,
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1bc'),
#   'Country': 'Ecuador',
#   'CountryCode': 'EC',
#   'Slug': 'ecuador',
#   'NewConfirmed': 1203,
#   'TotalConfirmed': 194876,
#   'NewDeaths': 61,
#   'TotalDeaths': 13562,
#   'NewRecovered': 0,
#   'TotalRecovered': 169804,
#   'first_case': '2020-03-01T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d1'),
#   'Country': 'Haiti',
#   'CountryCode': 'HT',
#   'Slug': 'haiti',
#   'NewConfirmed': 17,
#   'TotalConfirmed': 9313,
#   'NewDeaths': 0,
#   'TotalDeaths': 233,
#   'NewRecovered': 68,
#   'TotalRecovered': 8091,
#   'first_case': '2020-03-20T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e9'),
#   'Country': 'Liberia',
#   'CountryCode': 'LR',
#   'Slug': 'liberia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1595,
#   'NewDeaths': 0,
#   'TotalDeaths': 83,
#   'NewRecovered': 0,
#   'TotalRecovered': 1343,
#   'first_case': '2020-03-16T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f231'),
#   'Country': 'Syrian Arab Republic (Syria)',
#   'CountryCode': 'SY',
#   'Slug': 'syria',
#   'NewConfirmed': 86,
#   'TotalConfirmed': 8059,
#   'NewDeaths': 4,
#   'TotalDeaths': 426,
#   'NewRecovered': 65,
#   'TotalRecovered': 3689,
#   'first_case': '2020-03-22T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f18c'),
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 932,
#   'TotalConfirmed': 85084,
#   'NewDeaths': 17,
#   'TotalDeaths': 2464,
#   'NewRecovered': 585,
#   'TotalRecovered': 54990,
#   'first_case': '2020-02-25T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1d3'),
#   'Country': 'Honduras',
#   'CountryCode': 'HN',
#   'Slug': 'honduras',
#   'NewConfirmed': 891,
#   'TotalConfirmed': 109144,
#   'NewDeaths': 12,
#   'TotalDeaths': 2930,
#   'NewRecovered': 804,
#   'TotalRecovered': 48877,
#   'first_case': '2020-03-11T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1eb'),
#   'Country': 'Liechtenstein',
#   'CountryCode': 'LI',
#   'Slug': 'liechtenstein',
#   'NewConfirmed': 32,
#   'TotalConfirmed': 1318,
#   'NewDeaths': 0,
#   'TotalDeaths': 16,
#   'NewRecovered': 39,
#   'TotalRecovered': 1149,
#   'first_case': '2020-03-04T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f2'),
#   'Country': 'Malaysia',
#   'CountryCode': 'MY',
#   'Slug': 'malaysia',
#   'NewConfirmed': 851,
#   'TotalConfirmed': 68020,
#   'NewDeaths': 2,
#   'TotalDeaths': 365,
#   'NewRecovered': 658,
#   'TotalRecovered': 56969,
#   'first_case': '2020-01-25T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f19b'),
#   'Country': 'Belize',
#   'CountryCode': 'BZ',
#   'Slug': 'belize',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5854,
#   'NewDeaths': 0,
#   'TotalDeaths': 148,
#   'NewRecovered': 0,
#   'TotalRecovered': 3151,
#   'first_case': '2020-03-23T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b3'),
#   'Country': 'Croatia',
#   'CountryCode': 'HR',
#   'Slug': 'croatia',
#   'NewConfirmed': 3539,
#   'TotalConfirmed': 134881,
#   'NewDeaths': 55,
#   'TotalDeaths': 1916,
#   'NewRecovered': 2124,
#   'TotalRecovered': 110355,
#   'first_case': '2020-02-25T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ec'),
#   'Country': 'Lithuania',
#   'CountryCode': 'LT',
#   'Slug': 'lithuania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 62515,
#   'NewDeaths': 0,
#   'TotalDeaths': 519,
#   'NewRecovered': 0,
#   'TotalRecovered': 15077,
#   'first_case': '2020-02-28T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f213'),
#   'Country': 'Qatar',
#   'CountryCode': 'QA',
#   'Slug': 'qatar',
#   'NewConfirmed': 255,
#   'TotalConfirmed': 139256,
#   'NewDeaths': 1,
#   'TotalDeaths': 239,
#   'NewRecovered': 207,
#   'TotalRecovered': 136513,
#   'first_case': '2020-02-29T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1da'),
#   'Country': 'Ireland',
#   'CountryCode': 'IE',
#   'Slug': 'ireland',
#   'NewConfirmed': 268,
#   'TotalConfirmed': 73066,
#   'NewDeaths': 5,
#   'TotalDeaths': 2074,
#   'NewRecovered': 0,
#   'TotalRecovered': 23364,
#   'first_case': '2020-02-29T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1db'),
#   'Country': 'Israel',
#   'CountryCode': 'IL',
#   'Slug': 'israel',
#   'NewConfirmed': 1492,
#   'TotalConfirmed': 339619,
#   'NewDeaths': 6,
#   'TotalDeaths': 2883,
#   'NewRecovered': 811,
#   'TotalRecovered': 325260,
#   'first_case': '2020-02-21T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e7'),
#   'Country': 'Lebanon',
#   'CountryCode': 'LB',
#   'Slug': 'lebanon',
#   'NewConfirmed': 1842,
#   'TotalConfirmed': 131297,
#   'NewDeaths': 22,
#   'TotalDeaths': 1055,
#   'NewRecovered': 0,
#   'TotalRecovered': 83034,
#   'first_case': '2020-02-21T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f201'),
#   'Country': 'Namibia',
#   'CountryCode': 'NA',
#   'Slug': 'namibia',
#   'NewConfirmed': 61,
#   'TotalConfirmed': 14477,
#   'NewDeaths': 0,
#   'TotalDeaths': 151,
#   'NewRecovered': 97,
#   'TotalRecovered': 13697,
#   'first_case': '2020-03-14T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1b2'),
#   'Country': 'Costa Rica',
#   'CountryCode': 'CR',
#   'Slug': 'costa-rica',
#   'NewConfirmed': 1168,
#   'TotalConfirmed': 141340,
#   'NewDeaths': 8,
#   'TotalDeaths': 1739,
#   'NewRecovered': 505,
#   'TotalRecovered': 88226,
#   'first_case': '2020-03-06T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f226'),
#   'Country': 'Solomon Islands',
#   'CountryCode': 'SB',
#   'Slug': 'solomon-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 5,
#   'first_case': '2020-10-12T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1a5'),
#   'Country': 'Burundi',
#   'CountryCode': 'BI',
#   'Slug': 'burundi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 689,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 575,
#   'first_case': '2020-03-31T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1aa'),
#   'Country': 'Central African Republic',
#   'CountryCode': 'CF',
#   'Slug': 'central-african-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4918,
#   'NewDeaths': 0,
#   'TotalDeaths': 63,
#   'NewRecovered': 0,
#   'TotalRecovered': 1924,
#   'first_case': '2020-03-15T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f9'),
#   'Country': 'Mexico',
#   'CountryCode': 'MX',
#   'Slug': 'mexico',
#   'NewConfirmed': 11251,
#   'TotalConfirmed': 1133613,
#   'NewDeaths': 800,
#   'TotalDeaths': 107565,
#   'NewRecovered': 6750,
#   'TotalRecovered': 836567,
#   'first_case': '2020-02-28T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f1e4'),
#   'Country': 'Kyrgyzstan',
#   'CountryCode': 'KG',
#   'Slug': 'kyrgyzstan',
#   'NewConfirmed': 335,
#   'TotalConfirmed': 73513,
#   'NewDeaths': 2,
#   'TotalDeaths': 1277,
#   'NewRecovered': 478,
#   'TotalRecovered': 65189,
#   'first_case': '2020-03-18T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1f0'),
#   'Country': 'Madagascar',
#   'CountryCode': 'MG',
#   'Slug': 'madagascar',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17341,
#   'NewDeaths': 0,
#   'TotalDeaths': 251,
#   'NewRecovered': 0,
#   'TotalRecovered': 16657,
#   'first_case': '2020-03-20T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f207'),
#   'Country': 'Nigeria',
#   'CountryCode': 'NG',
#   'Slug': 'nigeria',
#   'NewConfirmed': 122,
#   'TotalConfirmed': 67960,
#   'NewDeaths': 1,
#   'TotalDeaths': 1177,
#   'NewRecovered': 409,
#   'TotalRecovered': 63839,
#   'first_case': '2020-02-28T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f217'),
#   'Country': 'Rwanda',
#   'CountryCode': 'RW',
#   'Slug': 'rwanda',
#   'NewConfirmed': 46,
#   'TotalConfirmed': 5994,
#   'NewDeaths': 1,
#   'TotalDeaths': 50,
#   'NewRecovered': 31,
#   'TotalRecovered': 5575,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f190'),
#   'Country': 'Argentina',
#   'CountryCode': 'AR',
#   'Slug': 'argentina',
#   'NewConfirmed': 7533,
#   'TotalConfirmed': 1440103,
#   'NewDeaths': 228,
#   'TotalDeaths': 39156,
#   'NewRecovered': 5107,
#   'TotalRecovered': 1268358,
#   'first_case': '2020-03-03T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f196'),
#   'Country': 'Bahrain',
#   'CountryCode': 'BH',
#   'Slug': 'bahrain',
#   'NewConfirmed': 133,
#   'TotalConfirmed': 87270,
#   'NewDeaths': 0,
#   'TotalDeaths': 341,
#   'NewRecovered': 106,
#   'TotalRecovered': 85463,
#   'first_case': '2020-02-24T00:00:00Z'},
#  None,
#  {'_id': ObjectId('5fc9391d328335e0ae73f21e'),
#   'Country': 'Saudi Arabia',
#   'CountryCode': 'SA',
#   'Slug': 'saudi-arabia',
#   'NewConfirmed': 249,
#   'TotalConfirmed': 357872,
#   'NewDeaths': 12,
#   'TotalDeaths': 5919,
#   'NewRecovered': 337,
#   'TotalRecovered': 347513,
#   'first_case': '2020-03-02T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f214'),
#   'Country': 'Republic of Kosovo',
#   'CountryCode': 'XK',
#   'Slug': 'kosovo',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 40117,
#   'NewDeaths': 0,
#   'TotalDeaths': 1026,
#   'NewRecovered': 0,
#   'TotalRecovered': 25586,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1ca'),
#   'Country': 'Ghana',
#   'CountryCode': 'GH',
#   'Slug': 'ghana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 51667,
#   'NewDeaths': 0,
#   'TotalDeaths': 323,
#   'NewRecovered': 0,
#   'TotalRecovered': 50547,
#   'first_case': '2020-03-14T00:00:00Z'},
#  {'_id': ObjectId('5fc9391d328335e0ae73f1de'),
#   'Country': 'Japan',
#   'CountryCode': 'JP',
#   'Slug': 'japan',
#   'NewConfirmed': 2456,
#   'TotalConfirmed': 153432,
#   'NewDeaths': 32,
#   'TotalDeaths': 2141,
#   'NewRecovered': 1844,
#   'TotalRecovered': 127148,
#   'first_case': '2020-01-22T00:00:00Z'},
#  None]
